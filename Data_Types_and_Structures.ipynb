# %%
#Q1 Create a string with your name and print it

name = "ashish"
print(name)

# %%
#Q2 Find length of "Hello World"

a = "Hello World"
print(len(a))

# %%
#Q3 First 3 characters

s = "Python Programming"
print(s[:3])

# %%
#Q4 Convert to uppercase

s = "hello"
print(s.upper())#

# %%
#Q5 Replace apple with orange

s = "I like apple"
print(s.replace("apple","orange"))

# %%
#Q6 Create list 1 to 5

l = [1,2,3,4,5]
print(l)

# %%
#Q7 Append 10

l = [1,2,3,4]
l.append(10)
print(l)

# %%
#Q8 Remove 3

l = [1,2,3,4,5]
l.remove(3)
print(l)

# %%
#Q9 Second element

l = ['a','b','c','d']
print(l[1])

# %%
#Q10 Reverse list

l = [10,20,30,40,50]
l.reverse()
print(l)

# %%
#Q11 Create tuple

t = (100,200,300)
print(t)

# %%
#Q12 Second last element

t = ('red','green','blue','yellow')
print(t[-2])

# %%
#Q13 Minimum number

t = (10,20,5,15)
print(min(t))

# %%
#Q14 Index of cat

t = ('dog','cat','rabbit')
print(t.index("cat"))

# %%
#Q15 Check kiwi

t = ("apple","banana","mango")
print("kiwi" in t)

# %%
#Q16 Create set

s = {'a','b','c'}
print(s)

# %%
#Q17 Clear set

s = {1,2,3,4,5}
s.clear()
print(s)

# %%
#Q18 Remove 4

s = {1,2,3,4}
s.remove(4)
print(s)

# %%
#Q19 Union

a = {1,2,3}
b = {3,4,5}
print(a.union(b))

# %%
#Q20 Intersection

a = {1,2,3}
b = {2,3,4}
print(a.intersection(b))

# %%
#Q21 Create dictionary

d = {"name":"ashish","age":20,"city":"ahmedabad"}
print(d)

# %%
#Q22 Add country

d = {"name":"John","age":25}
d["country"] = "USA"
print(d)

# %%
#Q23 Access name

d = {"name":"Alice","age":30}
print(d["name"])

# %%
#Q24 Remove age

d = {"name":"Bob","age":22,"city":"New York"}
del d["age"]
print(d)

# %%
#Q25 Check city key

d = {"name":"Alice","city":"Paris"}
print("city" in d)

# %%
#Q26 List, tuple, dictionary

l = [1,2,3]
t = (4,5,6)
d = {"a":1,"b":2}
print(l,t,d)

# %%
#Q27 Random list and sort

import random

l = []
for i in range(5):
    l.append(random.randint(1,100))

l.sort()
print(l)

# %%
#Q28 Third index

l = ["a","b","c","d","e"]
print(l[3])

# %%
#Q29 Combine dictionaries

d1 = {"a":1}
d2 = {"b":2}
d1.update(d2)
print(d1)

# %%
#Q30 List to set

l = ["a","b","c","a"]
s = set(l)
print(s)
